# %% [markdown]
# 05/06/2026

# %%
from vit_adaf_standalone_inference import run_vit_detection_on_visualisation

out = run_vit_detection_on_visualisation(
    input_raster=r"R:\path\to\visualisation.vrt",      # VRT or GeoTIFF
    model_weights=r"R:\path\to\segmentation_VIT.pt",  # checkpoint from the notebook
    output_gpkg=r"R:\path\to\vit_detections.gpkg",
    min_area=40,
    min_roundness=0.5,
    threshold=0.5,
    label="AO",
    batch_size=4,          # reduce to 1 if GPU memory is low
    device=None,           # auto: cuda if available, otherwise cpu
)
