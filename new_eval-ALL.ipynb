# %% [markdown]
# 21/09/2026
#
# # New Evaluation Measure
#
# ADAF implementation of new evaluation measures for archaeology, developed by Fiorucci et al. (2024).
#
# Redo all evaluations with new test dataset.

# %%
from adaf.eval import run_eval_metrics

# %% [markdown]
# ## Centroid-Based Measure

# %%
res_eval = run_eval_metrics(
    pred_path=r"r:\ML podatki\ml_results\adaf_retrained_2-512px.gpkg",
    gt_path=r"r:\ML podatki\archaeology\gomile_2026-09-02.gpkg",
    splti_pth=r"r:\ML podatki\learning_samples\ml_dataset_split_v2.gpkg",
    iou_threshold=0,
    file_tag="v3"
)
# Out:
# c:\Users\ncoz\AppData\Local\miniconda3\envs\spatial\Lib\site-packages\pyogrio\geopandas.py:382: UserWarning: More than one layer found in 'ml_dataset_split_v2.gpkg': 'ml_dataset_split_v2' (default), 'layer_styles'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %% [markdown]
# For loop

# %%
paths_list = [
    # r"r:\ML podatki\ml_results\adaf_bih_0-128px.gpkg",
    # r"r:\ML podatki\ml_results\adaf_bih_0-256px.gpkg",
    # r"r:\ML podatki\ml_results\adaf_bih_0-512px.gpkg",
    # r"r:\ML podatki\ml_results\adaf_bih_1-512px.gpkg",
    r"r:\ML podatki\ml_results\adaf_bih_3-512px.gpkg",
    r"r:\ML podatki\ml_results\adaf_irish.gpkg",
    r"r:\ML podatki\ml_results\adaf_retrained_1.gpkg",
    r"r:\ML podatki\ml_results\adaf_retrained_2-256px.gpkg",
    r"r:\ML podatki\ml_results\adaf_retrained_2-512px.gpkg",
    r"r:\ML podatki\ml_results\adaf_retrained_3-512px.gpkg"
]

for pred_path in paths_list:
    res_eval = run_eval_metrics(
        pred_path=pred_path,
        gt_path=r"r:\ML podatki\archaeology\gomile_2026-09-02.gpkg",
        splti_pth=r"r:\ML podatki\learning_samples\ml_dataset_split_v2.gpkg",
        iou_threshold=0,
        file_tag="v3"
    )
# Out:
# c:\Users\ncoz\AppData\Local\miniconda3\envs\spatial\Lib\site-packages\pyogrio\geopandas.py:382: UserWarning: More than one layer found in 'ml_dataset_split_v2.gpkg': 'ml_dataset_split_v2' (default), 'layer_styles'. Specify layer parameter to avoid this warning.
#   result = read_func(
# c:\Users\ncoz\AppData\Local\miniconda3\envs\spatial\Lib\site-packages\pyogrio\geopandas.py:382: UserWarning: More than one layer found in 'ml_dataset_split_v2.gpkg': 'ml_dataset_split_v2' (default), 'layer_styles'. Specify layer parameter to avoid this warning.
#   result = read_func(
# c:\Users\ncoz\AppData\Local\miniconda3\envs\spatial\Lib\site-packages\pyogrio\geopandas.py:382: UserWarning: More than one layer found in 'ml_dataset_split_v2.gpkg': 'ml_dataset_split_v2' (default), 'layer_styles'. Specify layer parameter to avoid this warning.
#   result = read_func(
# ...
